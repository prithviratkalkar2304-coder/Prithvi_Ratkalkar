# %% [markdown]
# <a href="https://colab.research.google.com/github/prithviratkalkar2304-coder/Prithvi_Ratkalkar/blob/main/Study%20of%20Conditional%20Statements%20/%20Exp6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Study of Conditional Statements
# Name: Prithvi Ratkalkar
# PRN: 25070123165
# Batch: ENTC A1
# Expt 6

# %%
# Check whether a number is positive or negative
num=int(input('Enter a number:'))
if num>=0:
  print('Number is positive')
else:
  print('Number is negative')

# %%
num=int(input('Enter a number:'))
if num>0:
  print('Number is positive')
elif num<0:
  print('Number is negative')
else:
  print('Number is 0')

# %%
# Even- Odd
num=int(input('Enter Number:'))
if num%2==0:
  print('Number is even')
else:
  print('Number is odd')

# %%
# Find the largest number
num1=int(input('Enter Number 1:'))
num2=int(input('Enter Number 2:'))

if num1>num2:
  print(num1,' is greater')
elif num1==num2:
  print('Both numbers are equal')
else:
  print(num2, ' is greater')

# %%
num1=int(input('Enter Number 1:'))
num2=int(input('Enter Number 2:'))
num3=int(input('Enter Number 3:'))

if num1>num2 | num1>num3:
  print(num1,' is greater')
elif num1<num2 | num2>num3:
  print(num2,' is greater')
elif num1==num2 | num1==num3:
  print('The numbers are equal')
else:
  print(num3,' is greater')

# %%
# Marks Avg
ecsf=int(input('Enter marks:'))
dcld=int(input('Enter marks:'))
amt=int(input('Enter marks:'))
cla=int(input('Enter marks:'))
feee=int(input('Enter marks:'))

avg= (ecsf+dcld+amt+cla+feee)/5
avg_percent=avg*100

if avg_percent >= 90:
  print("Grade: A")
elif avg_percent>=80 and avg_percent<90:
  print("Grade: B")
elif avg_percent>=70 and avg_percent< 80:
  print("Grade: c")
elif avg_percent>=60 and avg_percent < 70:
  print("Grade: D")
else:
  print('Fail')

# %%
# Leap Year or not
year=int(input('Enter year:'))

if (year%4==0 and year%100!=0) or (year%400==0):
  print(year,' is a leap year')
else:
  print(year,' is not a leap year')

# %%
#check if date is valid
date=input("Enter the date in {dd/mm/yyyy}:")
dd,mm,yyyy=date.split('/')
dd=int(dd)
mm=int(mm)
yyyy=int(yyyy)
# Determine max_dd based on month and leap year
if(mm==1 or mm==3 or mm==5 or mm==7 or mm==8 or mm==10 or mm==12):
 max_dd=31
elif(mm==4 or mm==6 or mm==9 or mm==11):
 max_dd=30
elif(mm==2):
    if(yyyy%4==0):
        max_dd=29
    else:
        max_dd=28
else: # Handle invalid month input for max_dd, although full validation comes next
    max_dd = 0 # Indicate an invalid month for initial calculation

# Validate the date (dd, mm, yyyy must be positive and dd within max_dd)
is_date_valid = False
if (dd >= 1 and dd <= max_dd and mm >= 1 and mm <= 12):
    is_date_valid = True

if is_date_valid:
    print("Valid date")

    # Calculate next date
    if dd < max_dd:
        dd += 1
    elif mm < 12: # dd == max_dd, but not December
        dd = 1
        mm += 1
    else: # dd == max_dd and mm == 12 (December 31st)
        dd = 1
        mm = 1
        yyyy += 1
    print("Next date is:", dd, "/", mm, "/", yyyy)
else:
 print("Invalid date")
# Out:
# Enter the date in {dd/mm/yyyy}:32/5/2066
# Invalid date

# %%
#Program to calculate the salary
basic_salary=int(input("Enter the basic salary:"))
if basic_salary<=10000:
   hra= 0.2*basic_salary
   da=0.8*basic_salary
elif basic_salary<=20000:
    hra=basic_salary*0.25
    da=basic_salary*0.9
else:
      hra=basic_salary*0.3
      da=basic_salary*0.5
      gross=basic_salary+hra+da
      print("Gross salary is:",gross)
# Out:
# Enter the basic salary:32456
# Gross salary is: 58420.8

# %%
# income tax
income=float(input('Enter annual income:'))
if income>250500 and income<=500000:
  tax=income*0.05
elif income>500000 and income<1000000:
  tax=income*0.20
elif income<1000000:
  tax=income*0.30

print("Income Tax applicable:",tax)

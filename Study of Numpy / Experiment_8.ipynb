# %% [markdown]
# <a href="https://colab.research.google.com/github/prithviratkalkar2304-coder/Prithvi_Ratkalkar/blob/main/Study%20of%20Numpy%20/%20Experiment_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name:Prithvi Ratkalkar
#
# PRN:25070123165
#
# Batch: ENTC-A1
#
# #Experiment-8
# #Tools for EDA-Numpy(UNIT-2)

# %%
import numpy as np

a = np.array(([10,20,30,40]))
b = np.array([[1,2,3],[4,5,6]])
print(a)
print(b)
# Out:
# [10 20 30 40]
# [[1 2 3]
#  [4 5 6]]

# %%
b.ndim
# Out:
# 2

# %%
a.shape
# Out:
# (2, 3)

# %%
b.shape
# Out:
# (2, 3)

# %%
a.dtype
# Out:
# dtype('int64')

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((3,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.eye((3))
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.arange(1,10,2)
# Out:
# array([1, 3, 5, 7, 9])

# %%
np.linspace(0,1,5)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
a+5
# Out:
# array([15, 25, 35, 45])

# %%
a*2
# Out:
# array([20, 40, 60, 80])

# %%
np.mean(a)
# Out:
# np.float64(25.0)

# %%
np.max(a)
# Out:
# np.int64(40)

# %%
np.median(a)
# Out:
# np.float64(25.0)

# %%
np.min(a)
# Out:
# np.int64(10)

# %%
np.sum(a)
# Out:
# np.int64(100)

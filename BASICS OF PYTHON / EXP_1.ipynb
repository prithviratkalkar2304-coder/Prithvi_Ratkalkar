# %% [markdown]
# <a href="https://colab.research.google.com/github/prithviratkalkar2304-coder/Prithvi_Ratkalkar/blob/main/BASICS%20OF%20PYTHON%20/%20EXP_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Prithvi Ratkalkar
#
# PRN:25070123165
#
# Batch: ENTC-A1
#
# #Basic Programs-Experiment-2

# %%
#First Python Program
print("Hello Welcome to Python")
# Out:
# Hello Welcome to Python

# %%
#Mutltiple Statments
print("Hello");print("How are you");print("Bye Bye");
# Out:
# Hello
# How are you
# Bye Bye

# %%
print("Hello!", end=" ")
print("How are you")
# Out:
# Hello! How are you

# %%
#print numbers
a=5
print(a)
print(231)
print(675644)
# Out:
# 5
# 231
# 675644

# %%
#initialising variables
x=4
x="hey"
print(x)
# Out:
# hey

# %%
#many variables
x, y, z="Age", "Name", "College"
a, b, c="18", "Akshat", "SIT"
print(x, end=" : ");print(a);print(y,  end=" : ");print(b);print(z,  end=" : ");print(c)
# Out:
# Age : 18
# Name : Akshat
# College : SIT

# %%
#Calculations
a=6
b=3
print("Addition=", a+b)
print("Subtraction=", a-b)
print("Multiplicaton=", a*b)
print("Division=", a/b)
# Out:
# Addition= 9
# Subtraction= 3
# Multiplicaton= 18
# Division= 2.0

# %%
#DatA TYPES
A=5
a=3.65
b="name"
f=True
g=5+8j
print(type(A))
print(type(a))
print(type(b))
print(type(f))
print(type(g))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %%
#Input From User
a=int(input("Enter a Number:"))
b=int(input("Enter a Number:"))
print(a+b)
print(a-b)
print(a*b)
print(a**b)
print(a/b)
# Out:
# Enter a Number:4
# Enter a Number:3
# 7
# 1
# 12
# 64
# 1.3333333333333333

# %%
#Calculate sum and avg of marks of students
M1=float(input("Enter a Number:"))
M2=float(input("Enter a Number:"))
M3=float(input("Enter a Number:"))
M4=float(input("Enter a Number:"))
M5=float(input("Enter a Number:"))
print(M1+M2+M3+M4+M5)
print((M1+M2+M3+M4+M5)/5)
# Out:
# Enter a Number:98
# Enter a Number:98
# Enter a Number:65
# Enter a Number:35
# Enter a Number:86
# 382.0
# 76.4

# %%
#Area of Rectangle
L=float(input("Enter a Number:"))
B=float(input("Enter a Number"))
print("Area of Rectangle", L*B)
# Out:
# Enter a Number:4
# Enter a Number5
# Area of Rectangle 20.0

# %%
#Area of Circle
r=float(input("Enter a radius"))
print("Area of Circle", (3.14*r*r))
# Out:
# Enter a radius2
# Area of Circle 12.56

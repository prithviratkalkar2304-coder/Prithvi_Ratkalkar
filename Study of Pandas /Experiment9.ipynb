# %% [markdown]
# <a href="https://colab.research.google.com/github/prithviratkalkar2304-coder/Prithvi_Ratkalkar/blob/main/Study%20of%20Pandas%20/Experiment9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name:Prithvi Ratkalkar
#
# PRN:25070123165
#
# Batch: ENTC-A1
#
# #Experiment-9
# #Study of Pandas Library(UNIT-2)

# %%
#Panda
'''Used for:
Structured data
EDA
Data Cleaning'''
# Out:
# 'Used for:\nStructured data\nEDA\nData Cleaning'

# %%
import pandas as pd
s = pd.Series([10,20,30,40])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
#Create DataFrame
data={
    "Name":["A","B","C"],
    "Marks":[85,95,69]
}
df=pd.DataFrame(data)
df
# Out:
#   Name  Marks
# 0    A     85
# 1    B     95
# 2    C     69

# %%
df.head()
df.tail()
# Out:
#   Name  Marks
# 0    A     85
# 1    B     95
# 2    C     69

# %%
#Find the structure of the DataFrame
df.shape
# Out:
# (3, 2)

# %%
df.ndim #(num of features-columns)
# Out:
# 2

# %%
df.size
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Marks   3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
#Display of Columns Names
df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
#Check Data Types of Each Column
df.dtypes
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
#Access Individual Column
df["Marks"]
# Out:
# 0    85
# 1    95
# 2    69
# Name: Marks, dtype: int64

# %%
#access specific row
df.loc[1]
# Out:
# Name      B
# Marks    95
# Name: 1, dtype: object

# %%
df.loc[2]
# Out:
# Name      C
# Marks    69
# Name: 2, dtype: object

# %%
# Add a new Column
df["Grade"] = ["First Class","Distinction","Second Class"]
df
# Out:
#   Name  Marks         Grade
# 0    A     85   First Class
# 1    B     95   Distinction
# 2    C     69  Second Class

# %%
#Update a data
df.loc[0,"Marks"]=87
df
# Out:
#   Name  Marks         Grade
# 0    A     87   First Class
# 1    B     95   Distinction
# 2    C     69  Second Class

# %%
#Delete a column
df.drop("Grade",axis=1, inplace=True)
df
# Out:
#   Name  Marks
# 0    A     87
# 1    B     95
# 2    C     69

# %%
#perform statistical analysis
df["Marks"].mean()
# Out:
# np.float64(83.66666666666667)

# %%
df['Marks'].min()
# Out:
# 69

# %%
df['Marks'].max()
# Out:
# 95

# %%
#Apply Condition(Filtering)
#Display Students scoring more than 80.
df[df['Marks']>80]
# Out:
#   Name  Marks
# 0    A     87
# 1    B     95

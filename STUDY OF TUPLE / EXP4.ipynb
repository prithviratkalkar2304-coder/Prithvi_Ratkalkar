# %% [markdown]
# <a href="https://colab.research.google.com/github/prithviratkalkar2304-coder/Prithvi_Ratkalkar/blob/main/STUDY%20OF%20TUPLE%20/%20EXP4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name:Prithvi Ratkalkar
#
# PRN:25070123165
#
# Batch: ENTC-A1
#
# #Experiment-4
# #Study of Tuple

# %%
#Python Tuples
# Create Tuples and Access Tuple items
thistuple=("Prithvi","Aaryan","Raj")
print(thistuple[-1])


Tp=(43,65,3,67,2,9,54,432)
print(Tp[2:5])
print(Tp[-4:-1])
print(Tp[2:])
print(Tp[:6])
print(Tp[1:5:2])
# Out:
# Raj
# (3, 67, 2)
# (2, 9, 54)
# (3, 67, 2, 9, 54, 432)
# (43, 65, 3, 67, 2, 9)
# (65, 67)

# %%
#Replacing in Tuple
Tp=(43,65,3,67,2,9,54,432)
Tp[1]=3
print(Tp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2303700313.py in <cell line: 0>()
#       1 #Replacing in Tuple
#       2 Tp=(43,65,3,67,2,9,54,432)
# ----> 3 Tp[1]=3
#       4 print(Tp)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Append items
Tp.append(5)
print(Tp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4217552614.py in <cell line: 0>()
#       1 #Append items
# ----> 2 Tp.append(5)
#       3 print(Tp)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
#Concating 2 tuples
t1=(4,5,6)
t2=(7,8,9)
t3=t1+t2
print(t3)
# Out:
# (4, 5, 6, 7, 8, 9)

# %%
#Problems-1
'''
A student's exam result is stored in a tuple containing 3 fixed fieds: Suject name,marks ,grage
WAP to:
*Store the Exam result into seperate variables
*Unpack the tuple elements into seperate variables
*Display the subject, marks, grades,
Check whether the student has scored 75 or more marks and print "Distinction" if the condition is satisfied
'''
Result=("Maths",87,"A")
Sub,marks,Grade=Result
print(Sub)
print(marks)
print(Grade)
#check for distinction
if(marks>=75):
    print("Distinction")
# Out:
# Maths
# 87
# A
# Distinction

# %%
#Problem-2

Attendence=("P","P","P","P","A","P","P","A","A","P")
print("Total Present:",Attendence.count("P"))
print("Total Absent:",Attendence.count("A"))
if(Attendence.count("A")>=1):
    print("Employee was absent atleast once")
# Out:
# Total Present: 7
# Total Absent: 3
# Employee was absent atleast once
